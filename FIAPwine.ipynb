# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("winequalityN.csv")

df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
wdRed = df[df["type"] == "red"]

# %%
wdRed
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 4898  red            7.4             0.700         0.00             1.9
# 4899  red            7.8             0.880         0.00             2.6
# 4900  red            7.8             0.760         0.04             2.3
# 4901  red           11.2             0.280         0.56             1.9
# 4902  red            7.4             0.700         0.00             1.9
# ...   ...            ...               ...          ...             ...
# 6492  red            6.2             0.600         0.08             2.0
# 6493  red            5.9             0.550         0.10             2.2
# 6494  red            6.3             0.510         0.13             2.3
# 6495  red            5.9             0.645         0.12             2.0
# 6496  red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
wdRed.isnull().sum()
# Out:
# type                    0
# fixed acidity           2
# volatile acidity        1
# citric acid             1
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      2
# sulphates               2
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wdRed.dropna()
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 4898  red            7.4             0.700         0.00             1.9
# 4899  red            7.8             0.880         0.00             2.6
# 4900  red            7.8             0.760         0.04             2.3
# 4901  red           11.2             0.280         0.56             1.9
# 4902  red            7.4             0.700         0.00             1.9
# ...   ...            ...               ...          ...             ...
# 6491  red            6.8             0.620         0.08             1.9
# 6492  red            6.2             0.600         0.08             2.0
# 6494  red            6.3             0.510         0.13             2.3
# 6495  red            5.9             0.645         0.12             2.0
# 6496  red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
wdRed.duplicated()
# Out:
# 4898    False
# 4899    False
# 4900    False
# 4901    False
# 4902     True
#         ...
# 6492    False
# 6493    False
# 6494     True
# 6495    False
# 6496    False
# Length: 1599, dtype: bool

# %%
wdRed.drop_duplicates()
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 4898  red            7.4             0.700         0.00             1.9
# 4899  red            7.8             0.880         0.00             2.6
# 4900  red            7.8             0.760         0.04             2.3
# 4901  red           11.2             0.280         0.56             1.9
# 4903  red            7.4             0.660         0.00             1.8
# ...   ...            ...               ...          ...             ...
# 6491  red            6.8             0.620         0.08             1.9
# 6492  red            6.2             0.600         0.08             2.0
# 6493  red            5.9             0.550         0.10             2.2
# 6495  red            5.9             0.645         0.12             2.0
# 6496  red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
wdRed.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1597.000000       1598.000000  1598.000000     1599.000000
# mean        8.322104          0.527738     0.271145        2.538806
# std         1.740767          0.179085     0.194744        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
wdRed2 = wdRed.drop(columns=["type"])

# %%
plt.figure(figsize=(16, 8))
sns.heatmap(wdRed2.corr(), annot=True, cmap="inferno")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16, 8))
plt.title("Distribuição de acidez volátil por qualidade de vinho")
plt.xlabel("Qualidade do vinho")
plt.ylabel("Acidez volátil")
sns.lineplot(data=wdRed,x = 'quality', y ='volatile acidity', palette='inferno')
plt.show()
# Out:
# C:\Users\vitor\AppData\Local\Temp\ipykernel_15968\2510195333.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=wdRed,x = 'quality', y ='volatile acidity', palette='inferno')

# %%
plt.figure(figsize=(16, 8))
plt.title("Distribuição do teor alcóolico por qualidade de vinho")
plt.xlabel("Qualidade do vinho")
plt.ylabel("Teor álcoolico")
sns.lineplot(data=wdRed,x = 'quality', y ='alcohol', palette='inferno')
plt.show()
# Out:
# C:\Users\vitor\AppData\Local\Temp\ipykernel_15968\2222845484.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=wdRed,x = 'quality', y ='alcohol', palette='inferno')

# %%
#Relação entre acidez volátil e teor álcoolico e relação entre teor álcoolico e qualidade do vinho.
corr1 = wdRed["alcohol"].corr(wdRed["volatile acidity"])
corr2 = wdRed["alcohol"].corr(wdRed["quality"])

data = {
    'variavel1' : ["alcohol", "alcohol"],
    'variavel2' : ["volatile acidity" ,"quality"],
    'correlação' : [corr1, corr2 ]
}

wncorr = pd.DataFrame(data)
wncorr
# Out:
#   variavel1         variavel2  correlação
# 0   alcohol  volatile acidity   -0.203671
# 1   alcohol           quality    0.476166

# %%
wdRedHighq = wdRed[wdRed["quality"] >= 7]
wdRedHighq
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 4905  red            7.3              0.65         0.00             1.2
# 4906  red            7.8              0.58         0.02             2.0
# 4914  red            8.5              0.28         0.56             1.8
# 4935  red            8.1              0.38         0.28             2.1
# 4960  red            7.5              0.52         0.16             1.9
# ...   ...            ...               ...          ...             ...
# 6439  red            7.4              0.25         0.29             2.2
# 6442  red            8.4              0.37         0.43             2.3
# 6447  red            7.4              0.36         0.30             1.8
# 6453  red            7.0              0.56         0.17             1.7
# 6482  red            6.7              0.32         0.44             2.4
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
# Qual a acidez volátil média dos vinhos de qualidade elevada?
meanalc = wdRedHighq["volatile acidity"].mean()
print(f"Média de acidez volátil dos vinhos de boa qualidade é de {round(meanalc * 100, 1)}%")
# Out:
# Média de acidez volátil dos vinhos de boa qualidade é de 40.6%

# %%
# https://www.blog.psicometriaonline.com.br/o-que-e-correlacao-de-pearson/
# Qual a relação entre teor álcoolico e qualidade do vinho?

corralc = wdRed["alcohol"].corr(wdRed["quality"])
print(f"A correlação entre teor álcoolico e qualidade do vinho é de {round(corralc, 2)}, sendo considerada moderada para Cohen e fraca para Rumsey")
# Out:
# A correlação entre teor álcoolico e qualidade do vinho é de 0.48, sendo considerada moderada para Cohen e fraca para Rumsey

# %%
# Há alguma relação entre acidez volátil e teor álcoolico?
corrvol = wdRed["alcohol"].corr(wdRed["volatile acidity"])
print(f"A correlação entre acidez volátil e teor álcoolico é de {round(corrvol, 2)}, dando a entender que são inversamente proporcionais e fracas")
# Out:
# A correlação entre acidez volátil e teor álcoolico é de -0.2, dando a entender que são inversamente proporcionais e fracas

# %%
# Há alguma relação entre acidez volátil e qualidade?
corrvolq = wdRed["volatile acidity"].corr(wdRed["quality"])
print(f"A correlação entre acidez volátil e qualidade é de {round(corrvolq, 2)}, dando a entender que são inversamente proporcionais e fracas")
# Out:
# A correlação entre acidez volátil e qualidade é de -0.39, dando a entender que são inversamente proporcionais e fracas
